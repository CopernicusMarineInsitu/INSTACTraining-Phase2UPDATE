# %% [markdown]
# <H2>MADATORY PYTHON LIBRARIES</H2>

# %%
import ftputil
import numpy as np
import pandas as pd
from shapely.geometry import box
import seaborn as sns
# %matplotlib inline
# Out:
# /home/protllan/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: DeprecationWarning: Python 2 suport will be removed in ftputil 4.0.0
#   if __name__ == '__main__':

# %% [markdown]
# <H2>AUXILIARY FUNCTIONS</H2>

# %%
def itemize_ftplink(indexfile):
    """returns the keys for the items resulting from splitting by '/' the file_name colummn in the index files"""
    if indexfile == 'index_history.txt':
        return ['access_protocol','blank', 'host', 'core', 'product_name', 'directory', 'platform_category', 'netCDF_file']
    elif indexfile == 'index_monthly.txt': 
        return ['access_protocol','blank', 'host', 'core', 'product_name', 'directory', 'platform_category', 'timestamp', 'netCDF_file']
    else:
        return ['access_protocol','blank', 'host', 'core', 'product_name', 'directory', 'timestamp', 'netCDF_file']

# %%
def itemize_netCDFname(indexfile):
    """returns the keys for the items resulting from splitting by '_' the netCDF filename"""
    if indexfile == 'index_history.txt': 
        return ['region', 'data', 'data_source', 'code', 'subsettingcode'] #RR_XX_YY_CODE<_ZZZ>.nc
    elif indexfile == 'index_monthly.txt': 
        return ['region', 'timestamp', 'data', 'data_source', 'code'] #RR_YYYYMM_XX_YY_CODE.nc
    else:
        return ['region', 'fixedname', 'data', 'data_source', 'code', 'timestamp'] #RR_LATEST_XX_YY_CODE_YYYYMMDD.nc

# %% [markdown]
# <h2> SET YOUR CREDENTIALS</h2>

# %%
user = '' #type CMEMS user name
password = '' #type CMEMS password

# %% [markdown]
# <h2> TARGET A PRODUCT, HOST AND INDEX FILE</h2>

# %%
product_name = 'INSITU_MED_NRT_OBSERVATIONS_013_035' #type aimed In Situ product 
host = 'nrt.cmems-du.eu' #type aimed host (nrt.cmems-du.eu or my.cmems-du)
index_file = 'index_latest.txt' #type aimed index file

# %% [markdown]
# <h2>INDEX FILE RAW INFORMATION</h2>

# %%
#connect to CMEMS FTP
with ftputil.FTPHost(host, user, password) as ftp_host: 
    #open the index file to read
    with ftp_host.open("Core"+'/'+product_name+'/'+index_file, "r") as indexfile:
        raw_index_info = pd.read_csv(indexfile, skiprows=5) #load it as pandas dataframe
raw_index_info.head()
# Out:
# /home/protllan/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: DeprecationWarning: `use_list_a_option` will default to `False` in ftputil 4.x.x
#   from ipykernel import kernelapp as app
#    #catalog_id                                          file_name  \
# 0  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 1  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 2  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 3  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 4  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
#
#    geospatial_lat_min  geospatial_lat_max  geospatial_lon_min  \
# 0            40.34783            41.34950             4.20067
# 1            39.11882            39.11882            24.98735
# 2            36.71326            36.71326            21.55295
# 3            36.51606            36.52572            -2.47165
# 4            35.84379            35.84379            21.83213
#
#    geospatial_lon_max   time_coverage_start     time_coverage_end  \
# 0             4.48367  2018-06-04T02:54:49Z  2018-06-04T20:14:27Z
# 1            24.98735  2018-06-04T03:02:30Z  2018-06-04T03:02:30Z
# 2            21.55295  2018-06-04T08:43:30Z  2018-06-04T08:43:30Z
# 3            -2.43642  2018-06-04T03:00:20Z  2018-06-04T20:59:20Z
# 4            21.83213  2018-06-04T09:49:00Z  2018-06-04T09:49:00Z
#
#                                             provider           date_update  \
# 0  IFREMER  Institut Francais de Recherche pour l...  2018-06-08T07:09:04Z
# 1                                          Euro-Argo  2018-06-04T05:05:14Z
# 2                                          Euro-Argo  2018-06-04T13:05:10Z
# 3  OGS  Istituto Nazionale di Oceanografia e di G...  2018-06-21T13:05:37Z
# 4   LOV  Laboratoire Oceanographique de Villefranche  2018-06-04T13:05:24Z
#
#   data_mode                                         parameters
# 0         R                      PRES PSAL FLU2 CNDC TEMP DOX2
# 1         R                                     PRES PSAL TEMP
# 2         R                                     PRES PSAL TEMP
# 3         R                                     PRES TEMP PSAL
# 4         R   PRES PSAL TEMP DOX2 DOWNWELLING_PAR DOWN_IRRA...

# %% [markdown]
# <h2>INDEX FILE ADVANCED INFORMATION</h2>

# %%
raw_index_info[itemize_ftplink(index_file)] = raw_index_info['file_name'].str.split('/',expand=True) #split the ftplink in items
raw_index_info[['netCDF_file_name','netCDF_file_extension']] = raw_index_info['netCDF_file'].str.split('.',expand=True) #split the netCDF name in bare name and extension
raw_index_info[itemize_netCDFname(index_file)]= raw_index_info['netCDF_file_name'].str.split('_',expand=True) #split the netCDF name in items
raw_index_info.head()
# Out:
#    #catalog_id                                          file_name  \
# 0  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 1  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 2  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 3  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
# 4  MYO-MOON-01  ftp://nrt.cmems-du.eu/Core/INSITU_MED_NRT_OBSE...
#
#    geospatial_lat_min  geospatial_lat_max  geospatial_lon_min  \
# 0            40.34783            41.34950             4.20067
# 1            39.11882            39.11882            24.98735
# 2            36.71326            36.71326            21.55295
# 3            36.51606            36.52572            -2.47165
# 4            35.84379            35.84379            21.83213
#
#    geospatial_lon_max   time_coverage_start     time_coverage_end  \
# 0             4.48367  2018-06-04T02:54:49Z  2018-06-04T20:14:27Z
# 1            24.98735  2018-06-04T03:02:30Z  2018-06-04T03:02:30Z
# 2            21.55295  2018-06-04T08:43:30Z  2018-06-04T08:43:30Z
# 3            -2.43642  2018-06-04T03:00:20Z  2018-06-04T20:59:20Z
# 4            21.83213  2018-06-04T09:49:00Z  2018-06-04T09:49:00Z
#
#                                             provider           date_update  \
# 0  IFREMER  Institut Francais de Recherche pour l...  2018-06-08T07:09:04Z
# 1                                          Euro-Argo  2018-06-04T05:05:14Z
# 2                                          Euro-Argo  2018-06-04T13:05:10Z
# 3  OGS  Istituto Nazionale di Oceanografia e di G...  2018-06-21T13:05:37Z
# 4   LOV  Laboratoire Oceanographique de Villefranche  2018-06-04T13:05:24Z
#
#     ...    directory timestamp                          netCDF_file  \
# 0   ...       latest  20180604     GL_LATEST_PR_CT_FNCM_20180604.nc
# 1   ...       latest  20180604  GL_LATEST_PR_PF_3901890_20180604.nc
# 2   ...       latest  20180604  GL_LATEST_PR_PF_3901957_20180604.nc
# 3   ...       latest  20180604  GL_LATEST_PR_PF_3901974_20180604.nc
# 4   ...       latest  20180604  GL_LATEST_PR_PF_6901765_20180604.nc
#
#                    netCDF_file_name netCDF_file_extension region fixedname  \
# 0     GL_LATEST_PR_CT_FNCM_20180604                    nc     GL    LATEST
# 1  GL_LATEST_PR_PF_3901890_20180604                    nc     GL    LATEST
# 2  GL_LATEST_PR_PF_3901957_20180604                    nc     GL    LATEST
# 3  GL_LATEST_PR_PF_3901974_20180604                    nc     GL    LATEST
# 4  GL_LATEST_PR_PF_6901765_20180604                    nc     GL    LATEST
#
#   data data_source     code
# 0   PR          CT     FNCM
# 1   PR          PF  3901890
# 2   PR          PF  3901957
# 3   PR          PF  3901974
# 4   PR          PF  6901765
#
# [5 rows x 27 columns]

# %% [markdown]
# <h2>PROVIDERS BREAKDOWN </h2>

# %%
#create empty dictionary for available providers
data = {} 
for provider in raw_index_info['provider'].unique().tolist(): data[provider] = 0
print(data)
# Out:
# {'HELLENIC CENTER FOR MARINE RESEARCH (HCMR)': 0, 'ISPRA - Istituto Superiore per la Protezione e la Ricerca Ambientale': 0, 'CNR-ISSIA': 0, 'ARSO - Slovenian Environment Agency': 0, 'IRD  Institut de recherche pour le developpement - Brest': 0, "Schapi - Service central d'hydrometeorologie et d'appui a la prevision des inondations": 0, 'NIB-MBS': 0, 'Bundesamt fur Seeschifffahrt und Hydrographie (BSH)': 0, 'Euro-Argo': 0, 'Puertos del Estado (Spain)': 0, 'Unknown institution': 0, 'Sistema de Observacion y prediccion Costero de las Islas Baleares (SOCIB) - Spain': 0, "INSU  Institut National des Sciences de l'Univers": 0, 'Atlantic Oceanographic and Meteorological Laboratory (AOML)  National Oceanic and Atmospheric Administration (NOAA)': 0, 'Mediterranean Institute of Oceanography - La Seyne sur Mer (MIO)': 0, 'LOV  Laboratoire Oceanographique de Villefranche': 0, "IFREMER  Institut Francais de Recherche pour l'Exploitation de la Mer": 0, 'OGS  Istituto Nazionale di Oceanografia e di Geofisica Sperimentale': 0, 'OGS (Istituto Nazionale di Oceanografia e di Geofisica Sperimentale)': 0, 'SHOM  Service Hydrographique et Oceanographique de la Marine': 0, 'SARTI Research Group. Electronics Dept. Universitat Politecnica de Catalunya (UPC)': 0, 'SOCIB (Spain)': 0, 'CEREMA  Centre Etudes et Expertise sur les Risques  Environnement  Mobilite et Amenagement': 0, 'Institute of Marine Sciences  Middle East Technical University (IMS-METU)': 0, 'JRC - Institute for Environment and Sustainability (IES)': 0, "Eaufrance - Service public d'information sur l'eau": 0}

# %%
#count unique platform's providers 
for provider in raw_index_info['provider'].unique().tolist():
    provider_subset = raw_index_info[raw_index_info['provider'] == provider]
    data[provider] = len(provider_subset['code'].unique().tolist())
data
# Out:
# {'ARSO - Slovenian Environment Agency': 3,
#  'Atlantic Oceanographic and Meteorological Laboratory (AOML)  National Oceanic and Atmospheric Administration (NOAA)': 1,
#  'Bundesamt fur Seeschifffahrt und Hydrographie (BSH)': 1,
#  'CEREMA  Centre Etudes et Expertise sur les Risques  Environnement  Mobilite et Amenagement': 8,
#  'CNR-ISSIA': 1,
#  "Eaufrance - Service public d'information sur l'eau": 2,
#  'Euro-Argo': 5,
#  'HELLENIC CENTER FOR MARINE RESEARCH (HCMR)': 14,
#  "IFREMER  Institut Francais de Recherche pour l'Exploitation de la Mer": 8,
#  "INSU  Institut National des Sciences de l'Univers": 4,
#  'IRD  Institut de recherche pour le developpement - Brest': 2,
#  'ISPRA - Istituto Superiore per la Protezione e la Ricerca Ambientale': 21,
#  'Institute of Marine Sciences  Middle East Technical University (IMS-METU)': 1,
#  'JRC - Institute for Environment and Sustainability (IES)': 5,
#  'LOV  Laboratoire Oceanographique de Villefranche': 15,
#  'Mediterranean Institute of Oceanography - La Seyne sur Mer (MIO)': 1,
#  'NIB-MBS': 1,
#  'OGS  Istituto Nazionale di Oceanografia e di Geofisica Sperimentale': 23,
#  'OGS (Istituto Nazionale di Oceanografia e di Geofisica Sperimentale)': 73,
#  'Puertos del Estado (Spain)': 32,
#  'SARTI Research Group. Electronics Dept. Universitat Politecnica de Catalunya (UPC)': 1,
#  'SHOM  Service Hydrographique et Oceanographique de la Marine': 33,
#  'SOCIB (Spain)': 4,
#  "Schapi - Service central d'hydrometeorologie et d'appui a la prevision des inondations": 16,
#  'Sistema de Observacion y prediccion Costero de las Islas Baleares (SOCIB) - Spain': 16,
#  'Unknown institution': 61}

# %%
provider_breakdown = pd.DataFrame(data=data.values(), index=data.keys(), columns = ['number'])
provider_breakdown
# Out:
#                                                     number
# HELLENIC CENTER FOR MARINE RESEARCH (HCMR)              14
# ISPRA - Istituto Superiore per la Protezione e ...      21
# CNR-ISSIA                                                1
# ARSO - Slovenian Environment Agency                      3
# IRD  Institut de recherche pour le developpemen...       2
# Schapi - Service central d'hydrometeorologie et...      16
# NIB-MBS                                                  1
# Bundesamt fur Seeschifffahrt und Hydrographie (...       1
# Euro-Argo                                                5
# Puertos del Estado (Spain)                              32
# Unknown institution                                     61
# Sistema de Observacion y prediccion Costero de ...      16
# INSU  Institut National des Sciences de l'Univers        4
# Atlantic Oceanographic and Meteorological Labor...       1
# Mediterranean Institute of Oceanography - La Se...       1
# LOV  Laboratoire Oceanographique de Villefranche        15
# IFREMER  Institut Francais de Recherche pour l'...       8
# OGS  Istituto Nazionale di Oceanografia e di Ge...      23
# OGS (Istituto Nazionale di Oceanografia e di Ge...      73
# SHOM  Service Hydrographique et Oceanographique...      33
# SARTI Research Group. Electronics Dept. Univers...       1
# SOCIB (Spain)                                            4
# CEREMA  Centre Etudes et Expertise sur les Risq...       8
# Institute of Marine Sciences  Middle East Techn...       1
# JRC - Institute for Environment and Sustainabil...       5
# Eaufrance - Service public d'information sur l'eau       2

# %%
provider_breakdown.plot.bar(figsize=(10,10), fontsize=15, subplots=True, color = sns.color_palette())
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a481b310>], dtype=object)

# %% [markdown]
# <h3>PROVIDER'S DATA SOURCES BREAKDOWN </h3>

# %%
provider = 'OGS'
provider_subset = raw_index_info[raw_index_info['provider'].str.contains(provider)]

# %%
#create empty dictionary for available platform_types
data = {} 
for data_source in provider_subset['data_source'].unique().tolist(): data[data_source] = 0
print(data)
# Out:
# {'MO': 0, 'PF': 0, 'DC': 0}

# %%
#count unique platform_code-plaform_types combos (same platform with code XXXX can works as several platform type: i.e vessels with TS (thermosalinometer) and CT (CTD))
combo = provider_subset['code']+'_'+provider_subset['data_source']
for combo in combo.unique():
    data[combo.split('_')[1]] = data[combo.split('_')[1]] + 1
print(data)
# Out:
# {'MO': 1, 'PF': 23, 'DC': 72}

# %%
provider_data_source_breakdown = pd.DataFrame(data=data.values(), index = data.keys(), columns = ['number'])
provider_data_source_breakdown
# Out:
#     number
# MO       1
# PF      23
# DC      72

# %%
provider_data_source_breakdown.plot.pie(figsize=(10,10), fontsize=15, subplots=True,autopct='%1.0f%%', colors = sns.color_palette())
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a482a910>], dtype=object)

# %%
provider_data_source_breakdown.plot.bar(figsize=(10,10), fontsize=15, color = sns.color_palette())
